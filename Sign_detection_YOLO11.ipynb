# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepachowdhari/MyProjects/blob/main/Sign_detection_YOLO11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 31.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import gdown
# download the data from g drive

url = "https://drive.google.com/file/d/1qV5xA-V6tBL49E2gcBxiDOTX6lAqPFbF/view?usp=sharing"
file_id = url.split("/")[-2]
print(file_id)

prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "sign_data.zip")
# Out:
# 1qV5xA-V6tBL49E2gcBxiDOTX6lAqPFbF
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1qV5xA-V6tBL49E2gcBxiDOTX6lAqPFbF
# To: /content/sign_data.zip
# 100%|██████████| 9.32M/9.32M [00:00<00:00, 52.4MB/s]
# 'sign_data.zip'

# %%
# !unzip sign_data.zip
# Out:
# Archive:  sign_data.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/No-sign-language1_41_jpeg.rf.1a6465652fe3acc711e5c6bf2b3de56d.jpg
#  extracting: test/images/WhatsApp-Image-2024-04-29-at-8-22-40-PM_jpeg.rf.f1353243e04a992ef6acc338d0f178da.jpg
#  extracting: test/images/hello-sign-language1_2_jpeg.rf.f5e166de0790996f6efd5dd560001910.jpg
#  extracting: test/images/i-love-you-sign-language1_13_jpeg.rf.8a658541a0d6e634f04d7f1fd1434fb7.jpg
#  extracting: test/images/i-love-you-sign-language1_42_jpeg.rf.37b776462ea3fd07af903d1b94b09c82.jpg
#  extracting: test/images/i-love-you-sign-language1_64_jpeg.rf.9520610b8f3e9628e1f63f07c13e1cac.jpg
#  extracting: test/images/i-love-you-sign-language1_98_jpeg.rf.6aa69b93fd9fdf74d8a04dbfc68efd87.jpg
#  extracting: test/images/thank-you-sign-language1_68_jpeg.rf.d032ed8b8fafdc3c006616a9b02617d0.jpg
# ...

# %%
# !yolo task=detect mode=train data="/content/data.yaml" model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image("/content/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
Image("/content/runs/detect/train/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train/val_batch0_pred.jpg", width=600)

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/9 /content/test/images/No-sign-language1_41_jpeg.rf.1a6465652fe3acc711e5c6bf2b3de56d.jpg: 640x640 2 Yess, 12.8ms
# image 2/9 /content/test/images/WhatsApp-Image-2024-04-29-at-8-22-40-PM_jpeg.rf.f1353243e04a992ef6acc338d0f178da.jpg: 640x640 2 Nos, 9.6ms
# image 3/9 /content/test/images/hello-sign-language1_2_jpeg.rf.f5e166de0790996f6efd5dd560001910.jpg: 640x640 2 Hellos, 1 Thank_you, 8.5ms
# image 4/9 /content/test/images/i-love-you-sign-language1_13_jpeg.rf.8a658541a0d6e634f04d7f1fd1434fb7.jpg: 640x640 1 Love_you, 8.2ms
# image 5/9 /content/test/images/i-love-you-sign-language1_42_jpeg.rf.37b776462ea3fd07af903d1b94b09c82.jpg: 640x640 1 Love_you, 8.2ms
# image 6/9 /content/test/images/i-love-you-sign-language1_64_jpeg.rf.9520610b8f3e9628e1f63f07c13e1cac.jpg: 640x640 1 Love_you, 8.6ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# !yolo task=detect mode=predict model= "/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/Sign_data_single.jpg" save=True
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/Sign_data_single.jpg: 384x640 (no detections), 51.7ms
# Speed: 3.8ms preprocess, 51.7ms inference, 22.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/runs/detect/predict2/Sign_data_single.jpg", width=600)
