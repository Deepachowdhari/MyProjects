# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepachowdhari/MyProjects/blob/main/YOLO11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 879.0/879.0 kB 14.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("test.jpeg")
results[0].show()
# Out:
# image 1/1 /content/test.jpeg: 640x480 4 persons, 2 boats, 1 cup, 392.0ms
# Speed: 19.7ms preprocess, 392.0ms inference, 39.3ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=758x1024>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-seg.pt")

# Perform object detection on an image
results = model("test.jpeg")
results[0].show()
# Out:
# ...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 70.9MB/s]
# image 1/1 /content/test.jpeg: 640x480 4 persons, 1 boat, 1 frisbee, 315.3ms
# Speed: 6.3ms preprocess, 315.3ms inference, 26.2ms postprocess per image at shape (1, 3, 640, 480)
# <PIL.Image.Image image mode=RGB size=758x1024>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-pose.pt")

# Perform object detection on an image
results = model("test.jpeg", save=True)
results[0].show()
# Out:
# ...
# 100%|██████████| 5.97M/5.97M [00:00<00:00, 73.7MB/s]
# image 1/1 /content/test.jpeg: 640x480 (no detections), 183.5ms
# Speed: 7.1ms preprocess, 183.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/pose/predict
# <PIL.Image.Image image mode=RGB size=758x1024>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("flower.jpeg", save=True)
results[0].show()
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 68.0MB/s]
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 14.3MB/s]
# image 1/1 /content/flower.jpeg: 224x224 perfume 0.34, cup 0.24, water_jug 0.10, teapot 0.07, pitcher 0.04, 30.6ms
# Speed: 26.1ms preprocess, 30.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=460x512>
